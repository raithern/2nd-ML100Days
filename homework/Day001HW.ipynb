# %% [markdown]
# 作業1

# %% [markdown]
# https://www.kaggle.com/ronitf/heart-disease-uci
# 1. 可透過分析了解病因及罹患可能性。
# 2. 資料是由David W. Aha (aha '@' ics.uci.edu)提供，
#         以 調查病患 年齡，性別，胸痛型，靜息血壓，血清膽固醇，空腹血糖，靜息心電圖結果，最大心率，運動誘發心絞痛，等信息收集。
# 3. 結構化資料
# 4. 可以分析所得患病可能性及原因，尋找符合條件但未患病者觀察其未來結果。

# %% [markdown]
# 作業2

# %% [markdown]
# 1. 如何提升業績，在最短時間及路程抵達客人目的地（可增加載客的次數，當載客次數增加，業績自然就增加）
# 2. 市區的車流量，擁擠時段，市區交通燈的位置及等待時長，資料收集可透過交通部網站獲得。
# 3. 結構化資料
# 4. 可嘗試行走所得出每個時段最快之路線，觀察所使用時長有沒有改善。

# %% [markdown]
# 作業3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5
x_lin = np.linspace(0,100,101)
y = (x_lin + np.random.rand(101)*5)*w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc=2)
plt.show()

# %%
def mean_absolute_error(y, yp):

    mae = MAE = sum(abs(y-yp))/len(y)
    return mae
MAE = mean_absolute_error(y, y_hat)
print("The mean absolute error is %.3f"%(MAE))
# Out:
# The mean absolute error is 7.441
